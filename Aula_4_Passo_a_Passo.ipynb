# %% [markdown]
# <a href="https://colab.research.google.com/github/miriam-silva/PLN/blob/main/Aula_4_Passo_a_Passo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Instalação e download de recursos (rodar 1x)
# !pip install -q spacy pandas
# !python -m spacy download pt_core_news_sm -q

import spacy
import pandas as pd
from spacy import displacy

nlp = spacy.load("pt_core_news_sm")

print("Ambiente configurado com sucesso.")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 41.6 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('pt_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# Ambiente configurado com sucesso.

# %%
# 1. POS Tagging
frase_exercicio = "O corretor apresentou o imóvel para o cliente ontem."
doc = nlp(frase_exercicio)

dados = []

for token in doc:
    dados.append({
        "Palavra": token.text,
        "Classe": token.pos_,
        "Classe detalhada": token.tag_
    })

tabela = pd.DataFrame(dados)

tabela
# Out:
#       Palavra Classe Classe detalhada
# 0           O    DET              DET
# 1    corretor   NOUN             NOUN
# 2  apresentou   VERB             VERB
# 3           o    DET              DET
# 4      imóvel   NOUN             NOUN
# 5        para    ADP              ADP
# 6           o    DET              DET
# 7     cliente   NOUN             NOUN
# 8       ontem    ADV              ADV
# 9           .  PUNCT            PUNCT

# %%
# 2. Visualização com displacy

from spacy import displacy

displacy.render(
    doc,
    style="dep",
    jupyter=True,
    options={
        "distance": 100,
        "collapse_punct": False
    }
)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pt" id="7554ad6235f14186abe5cf4ed7e728bb-0" class="displacy" width="1050" height="337.0" direction="ltr" style="max-width: none; height: 337.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">O</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">corretor</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
# ...

# %%
# 3. Extração do SN e do SV

# Encontrar a raiz da frase
raiz = [token for token in doc if token.dep_ == "ROOT"][0]

# Encontrar o sujeito
sujeito = [token for token in doc if token.dep_ == "nsubj"][0]

# Sintagma Nominal (SN)
sintagma_nominal = list(sujeito.subtree)

# Sintagma Verbal (SV)
sintagma_verbal = [
    token for token in raiz.subtree
    if token not in sintagma_nominal
]

print("Raiz da frase:", raiz.text)
print("Sujeito:", sujeito.text)
print("Sintagma Nominal (SN):", [token.text for token in sintagma_nominal])
print("Sintagma Verbal (SV):", [token.text for token in sintagma_verbal])
# Out:
# Raiz da frase: apresentou
# Sujeito: corretor
# Sintagma Nominal (SN): ['O', 'corretor']
# Sintagma Verbal (SV): ['apresentou', 'o', 'imóvel', 'para', 'o', 'cliente', 'ontem', '.']
