# %% [markdown]
# <a href="https://colab.research.google.com/github/miriam-silva/PLN/blob/main/Aula_4_Passo_a_Passo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Instalação e download de recursos (rodar 1x)
# !pip install -q spacy pandas
# !python -m spacy download pt_core_news_sm -q

import spacy
import pandas as pd
from spacy import displacy

nlp = spacy.load("pt_core_news_sm")

print("Ambiente configurado com sucesso.")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 91.2 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('pt_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# Ambiente configurado com sucesso.

# %%
frase_ancora = "O banco aprovou o empréstimo ontem."
doc_ancora = nlp(frase_ancora)

print([token.text for token in doc_ancora])
# Out:
# ['O', 'banco', 'aprovou', 'o', 'empréstimo', 'ontem', '.']

# %%
displacy.render(doc_ancora, style="dep", jupyter=True, options={"distance": 100, "collapse_punct": False})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pt" id="626c4b25aa024936bca97aa937c256b5-0" class="displacy" width="750" height="287.0" direction="ltr" style="max-width: none; height: 287.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">O</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">banco</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">aprovou</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">o</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">empréstimo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">ontem</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">PUNCT</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-626c4b25aa024936bca97aa937c256b5-0-0" stroke-width="2px" d="M70,152.0 C70,102.0 140.0,102.0 140.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-626c4b25aa024936bca97aa937c256b5-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,154.0 L62,142.0 78,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-626c4b25aa024936bca97aa937c256b5-0-1" stroke-width="2px" d="M170,152.0 C170,102.0 240.0,102.0 240.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-626c4b25aa024936bca97aa937c256b5-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M170,154.0 L162,142.0 178,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-626c4b25aa024936bca97aa937c256b5-0-2" stroke-width="2px" d="M370,152.0 C370,102.0 440.0,102.0 440.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-626c4b25aa024936bca97aa937c256b5-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M370,154.0 L362,142.0 378,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-626c4b25aa024936bca97aa937c256b5-0-3" stroke-width="2px" d="M270,152.0 C270,52.0 445.0,52.0 445.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-626c4b25aa024936bca97aa937c256b5-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M445.0,154.0 L453.0,142.0 437.0,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-626c4b25aa024936bca97aa937c256b5-0-4" stroke-width="2px" d="M470,152.0 C470,102.0 540.0,102.0 540.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-626c4b25aa024936bca97aa937c256b5-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M540.0,154.0 L548.0,142.0 532.0,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-626c4b25aa024936bca97aa937c256b5-0-5" stroke-width="2px" d="M270,152.0 C270,2.0 650.0,2.0 650.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-626c4b25aa024936bca97aa937c256b5-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M650.0,154.0 L658.0,142.0 642.0,142.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
# Encontrar a raiz da frase (geralmente o verbo principal)
raiz = [token for token in doc_ancora if token.dep_ == "ROOT"][0]
print("Raiz da frase (verbo principal):", raiz.text)

# Encontrar o sujeito (nsubj = nominal subject)
sujeito = [token for token in doc_ancora if token.dep_ == "nsubj"][0]
print("Sujeito:", sujeito.text)

# Sintagma Nominal (SN): o sujeito e tudo que depende dele (ex.: o artigo "O")
sintagma_nominal = list(sujeito.subtree)
print("Sintagma Nominal (SN):", [t.text for t in sintagma_nominal])

# Sintagma Verbal (SV): a raiz e tudo que depende dela, exceto o próprio SN
sintagma_verbal = [t for t in raiz.subtree if t not in sintagma_nominal]
print("Sintagma Verbal (SV):", [t.text for t in sintagma_verbal])
# Out:
# Raiz da frase (verbo principal): aprovou
# Sujeito: banco
# Sintagma Nominal (SN): ['O', 'banco']
# Sintagma Verbal (SV): ['aprovou', 'o', 'empréstimo', 'ontem', '.']

# %%
frase_ambigua = "Vi o menino com o telescópio."
doc_ambiguo = nlp(frase_ambigua)

displacy.render(doc_ambiguo, style="dep", jupyter=True, options={"distance": 100, "collapse_punct": False})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pt" id="d8cbb8368871478ab78277a118e7e10a-0" class="displacy" width="750" height="337.0" direction="ltr" style="max-width: none; height: 337.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Vi</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">o</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">menino</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">com</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">o</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">telescópio</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">PUNCT</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d8cbb8368871478ab78277a118e7e10a-0-0" stroke-width="2px" d="M170,202.0 C170,152.0 235.0,152.0 235.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d8cbb8368871478ab78277a118e7e10a-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M170,204.0 L162,192.0 178,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d8cbb8368871478ab78277a118e7e10a-0-1" stroke-width="2px" d="M70,202.0 C70,102.0 240.0,102.0 240.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d8cbb8368871478ab78277a118e7e10a-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M240.0,204.0 L248.0,192.0 232.0,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d8cbb8368871478ab78277a118e7e10a-0-2" stroke-width="2px" d="M370,202.0 C370,102.0 540.0,102.0 540.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d8cbb8368871478ab78277a118e7e10a-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M370,204.0 L362,192.0 378,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d8cbb8368871478ab78277a118e7e10a-0-3" stroke-width="2px" d="M470,202.0 C470,152.0 535.0,152.0 535.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d8cbb8368871478ab78277a118e7e10a-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M470,204.0 L462,192.0 478,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d8cbb8368871478ab78277a118e7e10a-0-4" stroke-width="2px" d="M70,202.0 C70,52.0 545.0,52.0 545.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d8cbb8368871478ab78277a118e7e10a-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M545.0,204.0 L553.0,192.0 537.0,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d8cbb8368871478ab78277a118e7e10a-0-5" stroke-width="2px" d="M70,202.0 C70,2.0 650.0,2.0 650.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d8cbb8368871478ab78277a118e7e10a-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M650.0,204.0 L658.0,192.0 642.0,192.0" fill="currentColor"/>
# </g>
# </svg></span>
